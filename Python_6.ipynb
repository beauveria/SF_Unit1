# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\User\Documents\python projects\SF_Projects\SF_Unit1/data_sf.csv')
small_df = df[df.columns[1:8]].head(25)
s = small_df['Nationality'].value_counts()
display(s)
# Out:
# Spain        4
# Belgium      3
# Germany      3
# Argentina    3
# Uruguay      3
# France       2
# England      1
# Portugal     1
# Brazil       1
# Croatia      1
# Slovenia     1
# Italy        1
# Poland       1
# Name: Nationality, dtype: int64

# %%
s.index
# Out:
# Index(['Spain', 'Belgium', 'Germany', 'Argentina', 'Uruguay', 'France',
#        'England', 'Portugal', 'Brazil', 'Croatia', 'Slovenia', 'Italy',
#        'Poland'],
#       dtype='object')

# %%
s.index[0]
# Out:
# 'Spain'

# %%
len(s.index)
# Out:
# 13

# %%
s.loc[s > 1]
# Out:
# Spain        4
# Belgium      3
# Germany      3
# Argentina    3
# Uruguay      3
# France       2
# Name: Nationality, dtype: int64

# %%
s = df['Club'].value_counts()
display(s)
# Out:
# V-Varen Nagasaki     30
# Shonan Bellmare      30
# FC Emmen             29
# De Graafschap        29
# Padova               29
#                      ..
# Dijon FCO             8
# Dinamo Zagreb         7
# Vitória Guimarães     7
# GD Chaves             7
# Atlético Mineiro      6
# Name: Club, Length: 650, dtype: int64

# %%
s.index[0:10]
# Out:
# Index(['V-Varen Nagasaki', 'Shonan Bellmare', 'FC Emmen', 'De Graafschap',
#        'Padova', 'Vissel Kobe', 'Blackpool', 'Doncaster Rovers',
#        'Cambridge United', 'Northampton Town'],
#       dtype='object')

# %%
s = df['Position'].value_counts(normalize=True)
display(s)
# Out:
# GK     0.127239
# ST     0.117237
# CB     0.108785
# CM     0.082732
# LB     0.077692
# RB     0.073505
# RM     0.059394
# LM     0.056447
# CDM    0.053578
# CAM    0.049081
# RCB    0.032411
# LCB    0.031713
# LW     0.018764
# RCM    0.018609
# RW     0.018376
# LCM    0.018066
# LDM    0.011476
# RDM    0.010700
# LS     0.009382
# RS     0.008839
# RWB    0.005428
# LWB    0.004652
# CF     0.003954
# LF     0.000620
# LAM    0.000465
# RF     0.000465
# RAM    0.000388
# Name: Position, dtype: float64

# %%
s = small_df['Age'].value_counts()
display(s)
# Out:
# 27    5
# 32    5
# 31    3
# 26    3
# 29    2
# 24    2
# 33    2
# 30    1
# 28    1
# 25    1
# Name: Age, dtype: int64

# %%
s = small_df['Wage'].value_counts(bins=4)
display(s)
# Out:
# (211750.0, 329500.0]     9
# (93528.999, 211750.0]    8
# (329500.0, 447250.0]     6
# (447250.0, 565000.0]     2
# Name: Wage, dtype: int64

# %%
small_df.loc[(small_df['Wage'] > s.index[3].left) & (small_df['Wage'] <= s.index[3].right)]
# Out:
#         Name  Age Nationality          Club      Value    Wage Position
# 0   L. Messi   31   Argentina  FC Barcelona  110500000  565000       RF
# 7  L. Suárez   31     Uruguay  FC Barcelona   80000000  455000       RS

# %%
small_df = df[df.columns[0:7]].head(25)
s = small_df['Wage'].value_counts(bins=4)
display(s)
s.index
s.index[3]
s.index[3].left
s.index[3].right
small_df['Wage'] > s.index[3].left
# Out:
# (211750.0, 329500.0]     9
# (93528.999, 211750.0]    8
# (329500.0, 447250.0]     6
# (447250.0, 565000.0]     2
# Name: Wage, dtype: int64
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# Name: Wage, dtype: bool

# %%
s = df['FKAccuracy'].value_counts(bins=5)
display(s)
# Out:
# (21.2, 39.4]     4859
# (39.4, 57.6]     3957
# (57.6, 75.8]     2108
# (2.908, 21.2]    1760
# (75.8, 94.0]      213
# Name: FKAccuracy, dtype: int64

# %%
display(df)
# Out:
#        Unnamed: 0                Name  Age Nationality                 Club  \
# 0               0            L. Messi   31   Argentina         FC Barcelona
# 1               1   Cristiano Ronaldo   33    Portugal             Juventus
# 2               2           Neymar Jr   26      Brazil  Paris Saint-Germain
# 3               3              De Gea   27       Spain    Manchester United
# 4               4        K. De Bruyne   27     Belgium      Manchester City
# ...           ...                 ...  ...         ...                  ...
# 12892       13121        J. Lundstram   19     England      Crewe Alexandra
# 12893       13122  N. Christoffersson   19      Sweden       Trelleborgs FF
# 12894       13123           B. Worman   16     England     Cambridge United
# 12895       13124      D. Walker-Rice   17     England      Tranmere Rovers
# 12896       13125           G. Nugent   16     England      Tranmere Rovers
#
# ...

# %%
small_df['Nationality'].unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium', 'Croatia',
#        'Uruguay', 'Slovenia', 'Poland', 'Germany', 'France', 'England',
#        'Italy'], dtype=object)

# %%
len(small_df['Nationality'].unique())
# Out:
# 13

# %%
small_df['Nationality'].nunique()
# Out:
# 13

# %%
df[(df.Nationality=='Spain')].Wage.value_counts(bins=4)
print(651/(651+11+6+3))
# Out:
# 0.970193740685544

# %%
df[(df.Nationality=='Spain')].Wage.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 3        260000
# 8        380000
# 13       285000
# 20       315000
# 30       315000
#           ...
# 11750      1000
# 11777      1000
# 11822      1000
# 11976      4000
# 12621      1000
# Name: Wage, Length: 671, dtype: int64>

# %%
#Укажите количество уникальных сборных (Nationality), к которым относятся футболисты, выступающие за клуб (Club) "Manchester United".
df[(df.Club=='Manchester United')].Nationality.nunique()
# Out:
# 13

# %%
#С помощью функции unique определите двух футболистов из Бразилии (Nationality = 'Brazil'), выступающих за клуб (Club) 'Juventus'.
df[(df.Nationality == 'Brazil')&(df.Club=='Juventus')].Name.unique()
# Out:
# array(['Alex Sandro', 'Douglas Costa'], dtype=object)

# %%
#С помощью функции value_counts с параметром bins разбейте всех футболистов сборной (Nationality) Аргентины ('Argentina') на 4 равные группы. Укажите, сколько футболистов в возрасте от 34.75 до 41 года в сборной Аргентины.
df[(df.Nationality == 'Argentina')].Age.value_counts(bins=4)
# Out:
# (22.25, 28.5]      200
# (15.974, 22.25]    197
# (28.5, 34.75]      128
# (34.75, 41.0]       49
# Name: Age, dtype: int64

# %%
#Сколько процентов футболистов из Испании (Nationality = 'Spain') имеют возраст Age) 21 год? 
#Введите с точностью до 2 знаков после запятой без указания знака % (например, 12.35).
df[(df.Nationality == 'Spain')].Age.value_counts(normalize=True)
# Out:
# 21    0.117735
# 22    0.095380
# 20    0.077496
# 23    0.071535
# 25    0.064083
# 27    0.062593
# 24    0.059613
# 28    0.053651
# 26    0.053651
# 29    0.047690
# 19    0.047690
# 18    0.038748
# 30    0.038748
# 31    0.032787
# 32    0.032787
# 33    0.031297
# 34    0.022355
# 17    0.013413
# 35    0.011923
# 36    0.010432
# 37    0.008942
# 39    0.002981
# 16    0.002981
# 38    0.001490
# Name: Age, dtype: float64

# %%
#Укажите, какой из клубов (Club) насчитывает большее количество футболистов возрастом (Age) старше 35 лет.
old_guys=df[df.Age>35].Club
old_guys.describe(include = ['object'])
# Out:
# count                       273
# unique                      212
# top       Club Atlético Huracán
# freq                          4
# Name: Club, dtype: object

# %%
df.groupby(['Club']).groups
# Out:
# {' SSV Jahn Regensburg': [1642, 2284, 2374, 2401, 2575, 2583, 2850, 2868, 3418, 3908, 3989, 4154, 5151, 5177, 5525, 5885, 6070, 6679, 7173, 7477, 8905, 9061, 10825, 12482], '1. FC Heidenheim 1846': [1060, 1805, 1978, 2050, 2066, 2926, 3584, 3605, 4312, 4457, 4783, 6818, 7160, 7166, 7460, 9475, 10052, 10565, 11217, 12236], '1. FC Kaiserslautern': [2931, 3590, 4270, 4413, 4475, 4483, 4709, 4779, 5079, 5325, 5403, 5855, 5917, 7295, 8784, 9496, 9964, 10019, 10122, 10671, 11500, 11970, 12222], '1. FC Köln': [166, 379, 899, 1399, 3415, 6904, 7052, 8892, 12171, 12376], '1. FC Magdeburg': [1967, 2069, 2152, 2569, 2886, 3030, 3300, 3332, 4436, 4913, 5002, 5033, 5493, 5768, 6329, 7046, 7595, 8387, 9626, 11125, 11400], '1. FC Nürnberg': [724, 1208, 1254, 1920, 4775, 5265, 5556, 5985, 8590, 8632, 9217, 9858, 10480], '1. FC Union Berlin': [1422, 1493, 2530, 2876, 3635, 3844, 4683, 4826, 11038, 11296, 12340], '1. FSV Mainz 05': [545, 670, 765, 1201, 1342, 6218, 6868, 8792, 10293, 10561, 10566], 'A
# ...

# %%
grouped_df = df.groupby(['Club']).sum()
display(grouped_df)
# Out:
#                        Unnamed: 0  Age     Value    Wage  Crossing  Finishing  \
# Club
#  SSV Jahn Regensburg       129124  609  15195000   90000      1104        944
# 1. FC Heidenheim 1846      117834  473  18290000   76000       961        860
# 1. FC Kaiserslautern       167351  544  11195000   33000      1106        918
# 1. FC Köln                  54865  225  46810000   92000       444        357
# 1. FC Magdeburg            116731  515  57525000   84000       948        903
# ...                           ...  ...       ...     ...       ...        ...
# Zagłębie Sosnowiec         220803  656   6815000   27000      1161       1007
# Çaykur Rizespor            119137  557  27515000  118000      1110        921
# Örebro SK                  224465  622   8465000   36000      1114        974
# Östersunds FK              136103  478  11030000   39000       944        805
# Śląsk Wrocław              172358  628   9170000   50000      1058       1054
#
# ...

# %%
grouped_df.loc['Ajax']['Wage']
# Out:
# 158000

# %%
grouped_df = df.groupby(['Club'])['Wage'].sum().sort_values(ascending=False)
print(grouped_df.head(5))
# Out:
# Club
# Real Madrid          4138000
# FC Barcelona         3967000
# Manchester City      3097000
# Manchester United    2357000
# Juventus             2335000
# Name: Wage, dtype: int64

# %%
grouped_df = df.groupby(['Position'])['Wage'].sum().sort_values(ascending=False)/1000000
print(grouped_df.head(20))
# Out:
# Position
# ST     11.873
# GK      8.784
# CB      7.476
# CM      6.194
# LB      6.096
# CAM     5.500
# LM      5.440
# RM      5.098
# RB      5.034
# CDM     4.921
# RCB     4.711
# LCB     3.989
# RW      3.276
# RCM     3.241
# LCM     3.145
# LW      2.945
# LS      1.866
# RDM     1.557
# RS      1.537
# LDM     1.516
# Name: Wage, dtype: float64

# %%
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean()
# Out:
#                      Wage        Age  ShotPower
# Nationality
# Afghanistan   1250.000000  22.500000  53.750000
# Albania       5931.034483  23.689655  54.551724
# Algeria      15810.810811  27.027027  56.567568
# Andorra       1000.000000  28.000000  58.000000
# Angola        7100.000000  24.700000  63.700000
# ...                   ...        ...        ...
# Uzbekistan    9000.000000  29.500000  71.500000
# Venezuela     6611.111111  23.638889  57.222222
# Wales         9529.411765  24.754902  48.558824
# Zambia        2833.333333  21.833333  66.833333
# Zimbabwe      5000.000000  26.555556  62.888889
#
# [156 rows x 3 columns]

# %%
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean().sort_values(['Wage'],ascending=False).head(10)
# Out:
#                             Wage        Age  ShotPower
# Nationality
# Dominican Republic  71000.000000  23.000000  75.500000
# Egypt               35545.454545  25.818182  59.363636
# Gabon               28900.000000  26.400000  56.900000
# Croatia             26722.222222  24.819444  54.305556
# Equatorial Guinea   25666.666667  28.000000  55.333333
# Belgium             20024.390244  24.030488  56.390244
# Ecuador             18333.333333  24.619048  60.666667
# Uruguay             17590.361446  26.771084  56.192771
# Brazil              17371.158392  27.898345  58.203310
# Algeria             15810.810811  27.027027  56.567568

# %%
#Посчитайте среднюю зарплату (Wage) и цену (Value) игроков разных позиций (Position). Представители какой позиции имеют самую высокую среднюю цену?
df.groupby(['Position'])[['Wage','Value']].mean().sort_values(['Value'],ascending=False)
# Out:
#                    Wage         Value
# Position
# LF         75125.000000  2.736250e+07
# RF        119000.000000  2.636583e+07
# LAM        61000.000000  1.324583e+07
# RAM        11800.000000  8.345000e+06
# LS         15421.487603  5.848430e+06
# LCM        13497.854077  4.318090e+06
# RCM        13504.166667  4.217604e+06
# RS         13482.456140  3.645833e+06
# LW         12169.421488  3.603099e+06
# RW         13822.784810  3.495738e+06
# LDM        10243.243243  3.369459e+06
# RCB        11270.334928  3.009055e+06
# CAM         8688.783570  2.963199e+06
# RDM        11282.608696  2.692717e+06
# LCB         9753.056235  2.636516e+06
# LM          7472.527473  2.466174e+06
# ST          7852.513228  2.157252e+06
# RM          6655.352480  2.138734e+06
# LWB         5783.333333  1.931333e+06
# CF          4862.745098  1.848627e+06
# CDM         7121.562952  1.658900e+06
# CM          5805.060918  1.617465e+06
# RWB         6000.000000  1.555571e+06
# ...

# %%
df1=df.groupby(['Nationality'])[['Club','Name']].nunique()
print (df1)
# Out:
#              Club  Name
# Nationality
# Afghanistan     4     4
# Albania        26    29
# Algeria        33    37
# Andorra         1     1
# Angola          9    10
# ...           ...   ...
# Uzbekistan      2     2
# Venezuela      34    36
# Wales          56   101
# Zambia          5     6
# Zimbabwe        8     9
#
# [156 rows x 2 columns]

# %%
#Посчитайте среднюю (mean) и медианную (median) зарплату (Wage) футболистов из разных клубов (Club).
#В скольких клубах средняя и медианная зарплаты совпадают?
df1=df.groupby(['Club'])[['Wage']].agg(['mean', 'median'])
counter=0
for row in df1.values:
    if row[0]==row[1]:
        counter+=1
print (counter)
# Out:
# 52

# %%
#Продолжаем работать с клубами, в которых средняя зарплата совпадает с медианной.
#Каков максимальный размер средней зарплаты в этой группе клубов?
#Как называется клуб, где игроки получают такую зарплату?
group = (df.groupby(['Club'])['Wage'].agg(['mean', 'median']))
new_df = (group[group['mean'] == group['median']])
new_df.sort_values(['mean'], ascending=False)
# Out:
#                            mean  median
# Club
# Cruzeiro                13000.0   13000
# Göztepe SK               7000.0    7000
# Brøndby IF               6000.0    6000
# Sunderland               4000.0    4000
# CD Feirense              4000.0    4000
# 1. FC Magdeburg          4000.0    4000
# Northampton Town         2500.0    2500
# Stade Brestois 29        2000.0    2000
# Jeonnam Dragons          2000.0    2000
# Pohang Steelers          2000.0    2000
# AJ Auxerre               2000.0    2000
# Grimsby Town             2000.0    2000
# Heracles Almelo          2000.0    2000
# Philadelphia Union       2000.0    2000
# Kashiwa Reysol           2000.0    2000
# CD Tondela               2000.0    2000
# Benevento                2000.0    2000
# FC Metz                  1500.0    1500
# PAOK                     1000.0    1000
# Orlando Pirates          1000.0    1000
# Panathinaikos FC         1000.0    1000
# Patriotas Boyacá FC      1000.0    1000
# ...

# %%
#С помощью функции groupby посчитайте сумму зарплат (Wage) футболистов клуба (Club) "Chelsea".
grouped_df = df.groupby(['Club'])['Wage'].sum().sort_values(ascending=False)
print(grouped_df.head(20))
# Out:
# Club
# Real Madrid            4138000
# FC Barcelona           3967000
# Manchester City        3097000
# Manchester United      2357000
# Juventus               2335000
# Liverpool              2163000
# FC Bayern München      2051000
# Chelsea                2035000
# Tottenham Hotspur      1841000
# Arsenal                1795000
# Paris Saint-Germain    1620000
# West Ham United        1221000
# Atlético Madrid        1143000
# Milan                  1134000
# Napoli                 1042000
# Everton                1014000
# Inter                   949000
# Roma                    854000
# Borussia Dortmund       789000
# AS Monaco               770000
# Name: Wage, dtype: int64

# %%
#Определите максимальную зарплату футболиста национальности (Nationality) Аргентина ("Argentina") 
#в возрасте 20 лет.
#пределите максимальную зарплату футболиста национальности (Nationality) Аргентина ("Argentina")
#в возрасте 30 лет.
args=df.loc[df['Nationality'] == 'Argentina'][['Name','Wage','Age']]
args.groupby(['Age'])[['Wage']].max().sort_values(['Wage'],ascending=False).head(10)
# Out:
#        Wage
# Age
# 31   565000
# 30   300000
# 24   205000
# 25   130000
# 28   115000
# 26   105000
# 22    72000
# 33    60000
# 20    54000
# 27    46000

# %%
#Определите минимальную зарплату футболиста национальности (Nationality) Аргентина ("Argentina") 
#в возрасте 30 лет
args=df.loc[df['Nationality'] == 'Argentina'][['Name','Wage','Age']]
args.groupby(['Age'])[['Wage']].min().sort_values(['Wage'],ascending=False).head(10)
# Out:
#      Wage
# Age
# 40   2000
# 39   2000
# 38   2000
# 37   2000
# 28   2000
# 16   1000
# 30   1000
# 36   1000
# 35   1000
# 34   1000

# %%
#Определите максимальную силу (Strength) и баланс (Balance) среди игроков клуба 
#(Club) "FC Barcelona" из Аргентины ("Argentina"). 
df.loc[(df['Nationality'] == 'Argentina')& (df['Club']=='FC Barcelona')][['Strength','Balance']]
# Out:
#    Strength  Balance
# 0        59       95

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Wage'],
index=['Nationality'],
columns=['Club'],
aggfunc='sum')
display(pivot)
# Out:
#                            Wage
# Club               FC Barcelona  Juventus Manchester United Real Madrid
# Nationality
# Argentina              565000.0  205000.0          206000.0         NaN
# Belgium                110000.0       NaN          230000.0    240000.0
# Bosnia Herzegovina          NaN  180000.0               NaN         NaN
# Brazil                 465000.0  335000.0           91000.0    570000.0
# Chile                  205000.0       NaN          215000.0         NaN
# Costa Rica                  NaN       NaN               NaN    195000.0
# Croatia                260000.0  160000.0               NaN    420000.0
# Dominican Republic          NaN       NaN               NaN    140000.0
# Ecuador                     NaN       NaN          120000.0         NaN
# England                     NaN       NaN          478000.0         NaN
# France                 495000.0  145000.0          375000.0    459000.0
# ...

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Name'],
index=['Nationality'],
columns=['Club'],
aggfunc='count',
fill_value=0)
display(pivot)
pivot.loc['Spain']['Name']['Manchester United']
# Out:
#                            Name
# Club               FC Barcelona Juventus Manchester United Real Madrid
# Nationality
# Argentina                     1        1                 2           0
# Belgium                       1        0                 1           1
# Bosnia Herzegovina            0        1                 0           0
# Brazil                        2        2                 1           2
# Chile                         1        0                 1           0
# Costa Rica                    0        0                 0           1
# Croatia                       1        1                 0           1
# Dominican Republic            0        0                 0           1
# Ecuador                       0        0                 1           0
# England                       0        0                 6           0
# France                        3        1                 2           3
# Germany                       1        1                 0           1
# ...

# %%
#Создайте сводную таблицу, содержащую сведения о количестве игроков, 
#занимающих разные позиции в каждом клубе. Отсутствующие значения замените нулями.
#Каково среднее количество вратарей (GK) в клубе? Ответ округлите до трёх цифр после запятой.
pivot = df.pivot_table(columns = 'Position', index = 'Club', values = 'Name', aggfunc = 'count', fill_value=0)
display(pivot)
round(pivot['GK'].mean(),3)
#Используя таблицу, созданную на предыдущем шаге, определите,
#сколько клубов не содержат данных о центральных полузащитниках. (CM)
pivot['CM'].value_counts()
# Out:
# Position               CAM  CB  CDM  CF  CM  GK  LAM  LB  LCB  LCM  ...  RB  \
# Club                                                                ...
#  SSV Jahn Regensburg     0   5    1   0   2   3    0   2    0    0  ...   2
# 1. FC Heidenheim 1846    1   3    0   0   1   2    0   2    1    0  ...   2
# 1. FC Kaiserslautern     0   3    3   0   0   3    0   2    1    0  ...   2
# 1. FC Köln               0   1    1   0   2   3    0   0    0    0  ...   1
# 1. FC Magdeburg          0   4    0   1   0   3    0   1    1    1  ...   0
# ...                    ...  ..  ...  ..  ..  ..  ...  ..  ...  ...  ...  ..
# Zagłębie Sosnowiec       3   2    2   0   0   3    0   3    1    0  ...   1
# Çaykur Rizespor          1   2    5   0   0   3    0   2    1    0  ...   3
# Örebro SK                0   4    0   0   1   3    0   0    1    1  ...   0
# Östersunds FK            1   1    0   1   3   3    0   2    1    1  ...   1
# ...

# %%
#С помощью сводной таблицы и функции loc посчитайте, сколько получают ("Wage") русские футболисты 
#("Russia"), играющие за ФК "AS Monaco"
russians=df.loc[(df['Nationality'] == 'Russia') & (df['Club']=='AS Monaco')][['Club','Name','Wage']]
display(russians)
# Out:
#           Club        Name   Wage
# 365  AS Monaco  A. Golovin  61000

# %%
#Создайте сводную таблицу, содержащую сведения о средней скорости футболистов,
#занимающих разные позиции (Position) в разных футбольных клубах (Club).

#Основываясь на данных таблицы, отметьте три позиции, представители которых в среднем обладают
#самой высокой скоростью.
pivot = df.pivot_table(columns = 'Position', index = 'Club', values = 'SprintSpeed', aggfunc = 'mean')
display(pivot)
print(pivot['RB'].mean(),'RB')
print(pivot['LM'].mean(), 'LM')
print(pivot['RM'].mean(),'RM')
print(pivot['CF'].mean(), 'CF')
print(pivot['RS'].mean(),'RS')
#Используя таблицу, созданную на предыдущем шаге, отметьте названия трёх клубов, в которых 
#центральные форварды (ST) обладают наибольшей средней скоростью.
display(pivot.sort_values(['ST'],ascending=False).head(3))
# Out:
# Position                CAM         CB        CDM    CF         CM         GK  \
# Club
#  SSV Jahn Regensburg    NaN  46.600000  82.000000   NaN  61.000000  33.000000
# 1. FC Heidenheim 1846  68.0  61.333333        NaN   NaN  68.000000  41.000000
# 1. FC Kaiserslautern    NaN  59.000000  65.666667   NaN        NaN  42.666667
# 1. FC Köln              NaN  60.000000  32.000000   NaN  68.500000  33.000000
# 1. FC Magdeburg         NaN  60.000000        NaN  64.0        NaN  39.333333
# ...                     ...        ...        ...   ...        ...        ...
# Zagłębie Sosnowiec     73.0  46.500000  66.000000   NaN        NaN  39.000000
# Çaykur Rizespor        74.0  58.000000  62.800000   NaN        NaN  47.000000
# Örebro SK               NaN  60.750000        NaN   NaN  63.000000  33.666667
# Östersunds FK          67.0  76.000000        NaN  77.0  56.333333  32.666667
# Śląsk Wrocław           NaN  62.000000  66.666667   NaN  72.000000  30.666667
#
# ...

# %%
df['Position'].unique()
# Out:
# array(['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
#        'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
#        'RW', 'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB'], dtype=object)
